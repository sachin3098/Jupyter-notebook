# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxis=sns.load_dataset('taxis')

# %%
taxis.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
taxis.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
sns.boxplot(taxis.total)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total'>

# %%
sns.boxplot(y=taxis.total, x=taxis.pickup_borough, hue=taxis.payment)    #we differnet total fair based on cash and credit card.
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
#fOR Horizontal graph just change X-axis and Y-axis.

# %%
sns.boxplot(x=taxis.total, y=taxis.pickup_borough, hue=taxis.payment)
# Out:
# <AxesSubplot:xlabel='total', ylabel='pickup_borough'>

# %%
sns.boxplot(x=taxis.total, y=taxis.pickup_borough, hue=taxis.payment,order=['Brooklyn','Bronx','Manahattan','Queens'])
# Out:
# <AxesSubplot:xlabel='total', ylabel='pickup_borough'>

# %%
sns.boxplot(x=taxis.total, y=taxis.pickup_borough, hue=taxis.payment, color='g') #change color of bars.
# Out:
# <AxesSubplot:xlabel='total', ylabel='pickup_borough'>

# %%
sns.boxplot(x=taxis.total, y=taxis.pickup_borough, hue=taxis.payment, color='g',width=1)   #change widht of black line
# Out:
# <AxesSubplot:xlabel='total', ylabel='pickup_borough'>

# %%
sns.boxplot(x=taxis.total, y=taxis.pickup_borough, hue=taxis.payment, showcaps=False)
# Out:
# <AxesSubplot:xlabel='total', ylabel='pickup_borough'>
